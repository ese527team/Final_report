# %% [markdown]
# # 1. Reading data

# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import datetime
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from matplotlib import pyplot as plt
from dateutil.relativedelta import relativedelta
import datetime
import pandas as pd
import numpy as np
from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
from fitter import Fitter, get_common_distributions, get_distributions
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.datasets import fetch_species_distributions, load_digits
from sklearn.model_selection import GridSearchCV, LeaveOneOut, train_test_split
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import KFold 
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score
from sklearn import tree
import math
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import sklearn.decomposition as dp
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoLarsIC
from sklearn.preprocessing import MinMaxScaler

import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold

from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("data_AP.csv",dtype={'Symbol': np.str},parse_dates=['Accper'])
# Out:
# C:\Users\JanRuoYu\AppData\Local\Temp\ipykernel_28576\4155429469.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = pd.read_csv("data_AP.csv",dtype={'Symbol': np.str},parse_dates=['Accper'])

# %%
tier25=data.iloc[:,-1].quantile(0.25)
tier75=data.iloc[:,-1].quantile(0.75)
data['classification']=0
for i in range(0,len(data.iloc[:,-1])):
    if (data.iloc[i,-2]<=tier25):
        data.iloc[i,-1]=-1
    elif (data.iloc[i,-2]>=tier75):
        data.iloc[i,-1]=1
    else:
        data.iloc[i,-1]=0
data
data['classification']=data['classification'].astype(int)

# %%
data
# Out:
#          Stkcd     Accper  Current_Ratio  Liquidity_Ratio  Cash_Ratio  \
# 0      0055.HK 2019-03-31       1.042785         0.577486    0.163058
# 1      0055.HK 2019-09-30       1.028640         0.607188    0.197985
# 2      0055.HK 2019-12-31       1.018991         0.630694    0.171091
# 3      0055.HK 2020-03-31       1.035491         0.623834    0.177662
# 4      0055.HK 2020-06-30       1.022618         0.584835    0.154379
# ...        ...        ...            ...              ...         ...
# 26132  ZZ-B.ST 2017-12-31       1.252963         0.967910    0.217087
# 26133  ZZ-B.ST 2018-06-30       1.369232         0.936780    0.326114
# 26134  ZZ-B.ST 2018-09-30       1.425613         0.955237    0.354545
# 26135  ZZ-B.ST 2018-12-31       1.069262         0.834902    0.094393
# 26136  ZZ-B.ST 2020-06-30       1.198030         1.173184    0.374820
#
#        Cash_Flow_Interest_Coverage_Ratio  Asset-liability_Ratio  Equity_Ratio  \
# 0                              19.986092               0.270758      0.371286
# 1                             365.451594               0.269749      0.369392
# 2                             204.414341               0.278266      0.385551
# 3                             -68.529810               0.269218      0.368398
# 4                               6.187099               0.257824      0.347390
# ...                                  ...                    ...           ...
# 26132                          -6.218580               0.636977      1.754648
# 26133                           2.875350               0.577800      1.368543
# 26134                          -0.779157               0.590018      1.439129
# 26135                           1.851293               0.663207      1.969187
# 26136                           3.295919               0.555680      1.250628
#
#        Total_Assets_Growth_Rate  Net_Profit_Growth_Rate  ...  \
# 0                     -0.005702                0.100264  ...
# 1                      0.019587                0.243492  ...
# 2                      0.047187                0.379693  ...
# 3                      0.039166               -0.762738  ...
# 4                      0.026595               -0.402941  ...
# ...                         ...                     ...  ...
# 26132                  0.391041               -0.524148  ...
# 26133                  0.333473                0.312685  ...
# 26134                  0.393759                0.371169  ...
# 26135                  0.157210                2.354460  ...
# 26136                 -0.018317               -0.688828  ...
#
#        Return_On_Assets  Return_On_Net_Assets          EBIT  \
# 0              0.021926              0.020527  1.380945e+08
# 1              0.055420              0.053246  3.517456e+08
# 2              0.073880              0.072159  4.763158e+08
# 3              0.005578              0.004640  3.665077e+07
# 4              0.022913              0.023732  1.482274e+08
# ...                 ...                   ...           ...
# 26132          0.024385              0.026696  1.318273e+08
# 26133          0.031812              0.054694  2.142928e+08
# 26134          0.045464              0.076671  3.175173e+08
# 26135          0.051099              0.085100  3.466858e+08
# 26136          0.012027              0.010181  1.089101e+08
#
#        Operating_Profit_Margin  Cost_Profit_Margin  Cash-To-Profit_Ratio  \
# 0                     0.071808            0.079216              0.656901
# 1                     0.069937            0.085160              1.590517
# 2                     0.071424            0.085806              1.533349
# 3                     0.051783            0.074622             -6.306631
# 4                     0.104064            0.151667              0.245828
# ...                        ...                 ...                   ...
# 26132                 0.041494            0.048548             -3.275803
# 26133                 0.164012            0.206903              0.617738
# 26134                 0.168826            0.215357             -0.196121
# 26135                 0.079311            0.149121              0.790663
# 26136                 0.109587            0.119419              3.163297
#
#        Return_On_Investment       EPS  Future_EPS  classification
# 0                  0.004662  0.050030    0.092089               0
# 1                  0.014966  0.112168    0.156581               0
# 2                  0.020098  0.156581    0.007666              -1
# 3                  0.012596  0.007666    0.044704              -1
# 4                  0.019409  0.044704    0.074484              -1
# ...                     ...       ...         ...             ...
# 26132              0.156993  0.099440    0.019583              -1
# 26133              0.042299  0.236143    0.340842               0
# 26134              0.042299  0.340842    0.199575               0
# 26135              0.042299  0.199575    0.017345              -1
# 26136              0.001549  0.057053    0.130499               0
#
# [26137 rows x 35 columns]

# %%
#feature and response

# %%
feature_global=data.iloc[:,2:-2]
response_global=data.iloc[:,-2]
response_global=response_global.values.reshape(-1,1)
response_global_class=data.iloc[:,-1]

# %%
#standard
X_tool = StandardScaler()
y_tool = StandardScaler()
x_std = X_tool.fit_transform(feature_global)
y_std = y_tool.fit_transform(response_global)
x_train,x_test,y_train,y_test = train_test_split(x_std,y_std,test_size=0.25)
x_train_class,x_test_class,y_train_class,y_test_class = train_test_split(x_std,response_global_class,test_size=0.25)

# %% [markdown]
# # 2. feature selection

# %% [markdown]
# ## 2.1 RF

# %%
def rf_feature(x,y):
    rf = RandomForestRegressor(n_jobs=10, n_estimators=500)
    rf.fit(x, y)
    im = rf.feature_importances_
    FS = pd.DataFrame({"Var": ["X%s" % (i+1) for i in range(len(im))],
                   'Name': data.columns[2:-2],
                   "Importance": im})
    FS["rank"] = FS["Importance"].rank(ascending=False)
    FS = FS.sort_values(by="Importance", ascending=True)
    FS.reset_index(drop=True, inplace=True)
    FS.to_csv("importance_rf.csv", index=False)

    plt.figure(figsize=(10,10))
    plt.barh(FS.iloc[:,1],FS.iloc[:,2])
    plt.xlabel("Random Forest Feature Importance")
    plt.savefig("rf_importance.png")

    feature_after_tuned=feature_global[FS[FS["rank"] <= 18].Name]
#     scaler = StandardScaler()
#     scaler.fit(feature_after_tuned)
#     feature_std = scaler.transform(feature_after_tuned)
#     feature_std=pd.DataFrame(feature_std,columns=feature_after_tuned.columns)

    #select 20 important features after reduction
    return(feature_after_tuned)

# %% [markdown]
# ## 2.2 PCA

# %%
def pca_feature(x):
    pca = PCA(n_components=0.85)
    #='mle'
    x_pca = pca.fit_transform(x)
#     x_train_pca,x_test_pca,y_train,y_test = train_test_split(x_std_pca,y_std,test_size=0.2)
    exp_var_pca = pca.explained_variance_ratio_
    cum_sum_eigenvalues = np.cumsum(exp_var_pca)
    
    plt.bar(range(0,len(exp_var_pca)), exp_var_pca, alpha=0.5, align='center', label='Individual explained variance')
    plt.step(range(0,len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where='mid',label='Cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal component index')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
    plt.savefig("pca_importance.png")
    
    return(x_pca)

# %% [markdown]
# ## 2.3 LASSO regression

# %%
def lasso_feature(x,y):
    ###lasso regression based on AIC
    lasso_aic = LassoLarsIC(criterion='aic', max_iter=50000)
    lasso_aic.fit(x,y)
    #ranks['Lasso_AIC'] = rank_to_dict(np.abs(lasso_aic.coef_), names)
    ###lasso regression based on BIC
    lasso_bic = LassoLarsIC(criterion='bic', max_iter=50000)
    lasso_bic.fit(x,y)
    #ranks['Lasso_BIC'] = rank_to_dict(np.abs(lasso_bic.coef_), names)
    
    bic = np.abs(lasso_bic.coef_)
    aic = np.abs(lasso_aic.coef_)
    mean = 1/2*(aic+bic)
    
    Lasso = pd.DataFrame({"Var_bic": ["X%s" % (i+1) for i in range(len(bic))],
                          "Var_aic": ["X%s" % (i+1) for i in range(len(aic))],
                       'Name': data.columns[2:-2],
                       "Importance_bic": bic,
                       "Importance_aic": aic,
                         "Importance_mean": mean})
    Lasso["rank"] = Lasso["Importance_mean"].rank(ascending=False)
    Lasso = Lasso.sort_values(by="Importance_mean", ascending=True)
    Lasso.reset_index(drop=True, inplace=True)
    Lasso.to_csv("importance_lasso.csv", index=False)
    plt.figure(figsize=(10,10))
    plt.barh(Lasso.iloc[:,2],Lasso.iloc[:,5])
    plt.xlabel("Lasso Regression Feature Importance")
    plt.savefig("Lasso_importance.png")
    
    feature_after_tuned=feature_global[Lasso[Lasso["rank"] <= 18].Name]
    
    #select 20 important features after reduction
    return(feature_after_tuned)

# %% [markdown]
# # 3. Model Selection

# %% [markdown]
# ## 3.0  5-fold cross_validation

# %%
# kfolds = KFold(n_splits=5,  shuffle=True)
# x_train,x_test,y_train,y_test = train_test_split(feature_after_tuned,response_global_class,test_size=0.25)
# x_train_1,x_train_2,y_train_1,y_train_2=train_test_split(x_train,y_train,test_size=0.5)

# %% [markdown]
# ## 3.1 KNN

# %%
# def smaller_FAT(x):
#     Q1 =x.quantile(0.25)
#     Q3 = x.quantile(0.75)
#     IQR = Q3 - Q1
#     x=x[(x < (Q1 - 1.5 * IQR)) | (x > (Q3 + 1.5 * IQR))==False]
#     x.insert(x.shape[1], 'classification', data.iloc[:,-1])
#     x=x.dropna()
#     return x
# smaller_df=smaller_FAT(feature_after_tuned)

# %%
def KNN(x_large_train,y_large_train,x_train,y_train,x_test,y_test):
    # Tune for KNN
    print("Here is the tuning for KNN")
    print ("Distance_measure=1 refers to Hamming distance, and 2 refers to Euclidean distance,3 refers to l3 distance")

    Acc=0
    count=0
    p3d = pd.DataFrame(columns=['Param 1','Param 2','Response Value']) 
    #################

    dist_name=['Hamming','Euclidean','L3']
    nameee=['Pair 1','Pair 2 ','Pair 3']
    ##################
    for j in range(1,8):
        for k in range(1,5):
            for dist in range(1,4):
                knn = KNeighborsClassifier(n_neighbors=j*5,leaf_size=k*9,p=dist)
                scores = cross_val_score(knn,x_train, y_train, scoring='accuracy', cv=kfolds, n_jobs=-1)
                #############
                p3d.loc[count]=[j*3,k*5,scores.mean()]
                count=count+1
                print("currently in KNN iteration "+str(count)+" out of 74")
                ###################
                if (scores.mean()>Acc):
                    Acc=scores.mean()
                    N_neighbors=j*3
                    Leaf_size=k*5
                    Distance_measure=dist
    for dist in range (0,3):
        fig = plt.figure()
        ax = fig.gca(projection='3d')
        ax.plot_trisurf(p3d['Param 1'], p3d['Param 2'], p3d['Response Value'], cmap=plt.cm.viridis, linewidth=0.2)
        ax.set_xlabel('Param 1')
        ax.set_ylabel('Param 2')
        ax.set_zlabel('Response Value')
        ax.set_title("KNN with Dist "+str(dist_name[dist]))
        plt.show()
        plt.savefig("KNN_tuning_with_dist "+dist_name[dist]+".png")


    print("The corresponding accuracy in tuning for KNN is "+str(Acc))
    print("The best hyper-parameter of KNN without deduction is:N_neighbors = "+str(N_neighbors)+",  Leaf_size = "+str(Leaf_size)+", and Distance_measure = "+str(Distance_measure))

    knn_pred = KNeighborsClassifier(n_neighbors=N_neighbors,leaf_size=Leaf_size,p=Distance_measure)
    knn_pred.fit(x_large_train,y_large_train)
    Acc_pred=knn_pred.score(x_test,y_test)
    print("The corresponding accuracy in tuning for KNN is "+str(Acc_pred))
    y_pred_knn=knn_pred.predict(x_test)
    return (y_pred_knn,Acc_pred)

# %% [markdown]
# ## 3.2 LSTM

# %%
def LSTM(x_train,y_train,x_test,y_test):
    Monitor=['loss']
    MIN_delta=[0]
    PATience=(np.linspace(start = 20, stop = 80, num = 2)).astype(int)
    ACTivation=["relu","tanh"]
    Loss=["mean_squared_error"]
    Optimizer=["RMSprop","Adam"]
    Acc=0
    count=0
    for i1 in range(0,1):
        for i2 in range (0,1):
            for i3 in range(0,2):
                for i4 in range(0,2):
                    for i5 in range(0,1):
                        for i6 in range(0,2):
                            for train, test in kfolds.split(x_train, y_train):
                                # 定义神经网络模型中的eaylu stop 如果测试集误差连续patienc次不再下降 则返回测试集对应的最佳模型 restore_best_weights 返回最佳
                                early_stopping = tf.keras.callbacks.EarlyStopping(monitor=Monitor[i1],min_delta=MIN_delta[i2], patience=PATience[i3], restore_best_weights=True)
                                # 定义lstm模型
                                model = tf.keras.Sequential([
                                    # 变成n*1序列
                                    tf.keras.layers.Reshape((x_train.shape[1], 1), input_shape=(x_train.shape[1],)),
                                    # lstm
                                    tf.keras.layers.LSTM(64, activation=ACTivation[i4], input_shape=(x_train.shape[1], 1)),
                                    # dropout 增加泛化能力
                                    tf.keras.layers.Dropout(0.2),
                                    # 输出层
                                    tf.keras.layers.Dense(1)
                                ])
                                # optimizer 优化器 求解算法 比如sgd是梯度下降 这个是nadam是sgd的改进
                                # loss 损失函数
                                model.compile(optimizer=Optimizer[i6], loss=Loss[i5])
                                # validation data 验证集
                                # epochs 迭代次数
                                # barch size 批次数量 每次更新模型参数的样本数量
                                # use_multiprocessing 多线程计算加快计算速度
                                history = model.fit(x_train, y_train,
                                                    epochs=2000,
                                                    verbose=0, # 0不查看迭代过程 可取0 1 2
                                                    batch_size=32,
                                                    use_multiprocessing=True,
                                                    callbacks=[early_stopping])
                                scores = model.evaluate(x_test,y_test, verbose=0)
                                count=count+1
                                print("currently in LSTM iteration "+str(count)+" out of 36")

                                if (scores>Acc):
                                    Acc=scores
                                    Mon=Monitor[i1]
                                    MIN=MIN_delta[i2]
                                    PAT=PATience[i3]
                                    ACT=ACTivation[i4]
                                    Opt=Optimizer[i6]
                                    LOSS=Loss[i5]


    print("The best hyper-parameter of is: The monitor is "+Monitor[i1]+" and MIN_delta[i2] is set to "+str(MIN_delta[i2]))
    print("The PAT is "+str(PAT)+" and ACT is set to "+ACT+" and OPT is "+Opt+" and loss function is "+LOSS)
    print("The accuracy in tuning is:",Acc)

    tier25_lstm=data.iloc[:,-1].quantile(0.25)
    tier75_lstm=data.iloc[:,-1].quantile(0.75)
    y_pred=model.predict(x_test)
    count=0
    for i in len(y_pred):
        if (y_pred[i]<=tier25_lstm):
            y_pred[i]=-1
            if (y_pred[i]==y_test[i]):
                count=count+1
        elif (y_pred[i]>=tier75_lstm):
            y_pred[i]=1
            if (y_pred[i]==y_test[i]):
                count=count+1
        else:
            y_pred[i]=0
            if (y_pred[i]==y_test[i]):
                count=count+1

    Acc_pred_lstm=count/len(y_pred)
    print("The accuracy of prediction using lstm is:"+str(Acc_pred_lstm))
    return(y_pred,Acc_pred_lstm)

# %% [markdown]
# ## 3.3 SVM

# %%
def SVM(x_large_train,y_large_train,x_train,y_train,x_test,y_test):
    # Tune for SVM
    print("Here is the tuning for SVM")
    print("Tolerance is for tolearance of maximum error in fitting, and Penalty is for penalty parameter")


    Kernel=['linear','rbf']
    Tol=[10e-4,10e-6]
    c=np.linspace(start = 3, stop = 7, num = 2)
    Acc=0

    count=0
    p3d = pd.DataFrame(columns=['Param 1','Param 2','Response Value']) 
    ##################

    for j in range(0,2):
        for k in range(0,2):
            for m in range(0,2):
                SVM=OneVsRestClassifier(svm.SVC(kernel=Kernel[j],tol=Tol[k],C=c[m]))
                scores = cross_val_score(SVM,x_train, y_train, scoring='accuracy', cv=kfolds, n_jobs=-1)
                #############
                p3d.loc[count]=[Tol[k],c[m],scores.mean()]
                count=count+1
                print("currently in SVM iteration "+str(count)+" out of 75")
                ###################
                if (scores.mean()>Acc):
                    Acc=scores.mean()
                    KERNEL=Kernel[j]
                    Tolerance=Tol[k]
                    Penalty=c[m]


    for dist in range (0,3):
        fig = plt.figure()
        ax = fig.gca(projection='3d')
        ax.plot_trisurf(p3d['Param 1'], p3d['Param 2'], p3d['Response Value'], cmap=plt.cm.viridis, linewidth=0.2)
        ax.set_xlabel('Param 1')
        ax.set_ylabel('Param 2')
        ax.set_zlabel('Response Value')
        ax.set_title("SVM with Kernel "+Kernel[dist])
        plt.show()


    print("The best hyper-parameter of pair "+str(i+1)+" is: KERNEL = "+KERNEL+",  Tolerance = "+str(Tolerance)+", and Penalty = "+str(Penalty))
    print("The corresponding accuracy in tunning for svm is "+str(Acc))

    SVM_pred = OneVsRestClassifie(svm.SVC(kernel=KERNEL,tol=Tolerance,C=Penalty))
    SVM_pred.fit(x_large_train,y_large_train)
    Acc_pred=SVM_pred.score(x_test,y_test)
    print("The corresponding accuracy in prediction for SVM is "+str(Acc_pred))
    y_pred_SVM=SVM_pred.predict(x_test)
    return (y_pred_SVM,Acc_pred)

# %% [markdown]
# ## 3.4 MLP

# %%
def MLP(x_train,y_train,x_test,y_test):
    parameter_space = {
        'hidden_layer_sizes': [(56,28,28,56),(120,60,120)],
        'activation': ['tanh'],
        'solver': ['adam'],
        'alpha': [0.01],
        'batch_size':['auto'],
        'learning_rate': ['adaptive'],
        "max_iter": [5000],
        'early_stopping':[True],
        'n_iter_no_change':[100],
        'tol':[10e-5],
        'verbose':[False]
    }
    mlp = MLPClassifier()
    estimator = GridSearchCV(mlp, parameter_space, n_jobs=-1,cv=3,scoring='accuracy')
    estimator.fit(x_train,y_train)
    y_pred =estimator.predict(x_test)
    print("best estimator",estimator.best_params_)
    Acc_pred_MLP=estimator.score(x_test, y_test)
    print("The predicted accuracy for MLP is: "+str(Acc_pred_MLP))
    return(y_pred,Acc_pred_MLP)

# %% [markdown]
# ## 3.5 Main Program

# %%
feature_selection=['Random_forest','PCA','Lasso']
Model_selection=['KNN','LSTM','SVM','MLP']
for i in range(0,3):
    if (i==0):
        feature_after_tuned=rf_feature(feature_global.values,response_global)
    if (i==1):
        feature_after_tuned=pca_feature(feature_global.values,response_global)
    if (i==2):
        feature_after_tuned=lasso_feature(feature_global.values,response_global)
        
        

    kfolds = KFold(n_splits=5,  shuffle=True)
    x_train,x_test,y_train,y_test = train_test_split(feature_after_tuned,response_global_class,test_size=0.2)
    x_train_1,x_train_2,y_train_1,y_train_2=train_test_split(x_train,y_train,test_size=0.3)
    y_pred = pd.DataFrame(columns=[]) 
    for j in range(0,4):
        if (j==0):
            print("The model is: "+feature_selection[i]+"+"+Model_selection[j])
            pred,Acc= KNN(x_train,y_train,x_train_2,y_train_2,x_test,y_test)
            y_pred.insert(y_pred.shape[1],feature_selection[i]+Model_selection[j], pred)
        if (j==1):
            print("The model is: "+feature_selection[i]+"+"+Model_selection[j])
            pred,Acc= LSTM(x_train_2,y_train_2,x_test,y_test)
            y_pred.insert(y_pred.shape[1],feature_selection[i]+Model_selection[j], pred)
        if (j==2):
            print("The model is: "+feature_selection[i]+"+"+Model_selection[j])
            pred,Acc= SVM(x_train,y_train,x_train_2,y_train_2,x_test,y_test)
            y_pred.insert(y_pred.shape[1],feature_selection[i]+Model_selection[j], pred)
        if (j==3):
            print("The model is: "+feature_selection[i]+"+"+Model_selection[j])
            pred,Acc= MLP(x_train,y_train,x_test,y_test)
            y_pred.insert(y_pred.shape[1],feature_selection[i]+Model_selection[j], pred)
# Out:
# C:\Users\JanRuoYu\AppData\Local\Temp\ipykernel_28576\457348620.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x, y)
# The model is: Random_forest+KNN
# Here is the tuning for KNN
# Distance_measure=1 refers to Hamming distance, and 2 refers to Euclidean distance,3 refers to l3 distance
# currently in KNN iteration 1 out of 74
# currently in KNN iteration 2 out of 74
# currently in KNN iteration 3 out of 74
# currently in KNN iteration 4 out of 74
# currently in KNN iteration 5 out of 74
# currently in KNN iteration 6 out of 74
# currently in KNN iteration 7 out of 74
# currently in KNN iteration 8 out of 74
# currently in KNN iteration 9 out of 74
# currently in KNN iteration 10 out of 74
# currently in KNN iteration 11 out of 74
# currently in KNN iteration 12 out of 74
# currently in KNN iteration 13 out of 74
# currently in KNN iteration 14 out of 74
# currently in KNN iteration 15 out of 74
# currently in KNN iteration 16 out of 74
# currently in KNN iteration 17 out of 74
# currently in KNN iteration 18 out of 74
# currently in KNN iteration 19 out of 74
# currently in KNN iteration 20 out of 74
# currently in KNN iteration 21 out of 74
# currently in KNN iteration 22 out of 74
# currently in KNN iteration 23 out of 74
# currently in KNN iteration 24 out of 74
# currently in KNN iteration 25 out of 74
# currently in KNN iteration 26 out of 74
# currently in KNN iteration 27 out of 74
# currently in KNN iteration 28 out of 74
# currently in KNN iteration 29 out of 74
# currently in KNN iteration 30 out of 74
# currently in KNN iteration 31 out of 74
# currently in KNN iteration 32 out of 74
# currently in KNN iteration 33 out of 74
# currently in KNN iteration 34 out of 74
# currently in KNN iteration 35 out of 74
# currently in KNN iteration 36 out of 74
# currently in KNN iteration 37 out of 74
# currently in KNN iteration 38 out of 74
# currently in KNN iteration 39 out of 74
# currently in KNN iteration 40 out of 74
# currently in KNN iteration 41 out of 74
# currently in KNN iteration 42 out of 74
# currently in KNN iteration 43 out of 74
# currently in KNN iteration 44 out of 74
# currently in KNN iteration 45 out of 74
# currently in KNN iteration 46 out of 74
# currently in KNN iteration 47 out of 74
# currently in KNN iteration 48 out of 74
# currently in KNN iteration 49 out of 74
# currently in KNN iteration 50 out of 74
# currently in KNN iteration 51 out of 74
# currently in KNN iteration 52 out of 74
# currently in KNN iteration 53 out of 74
# currently in KNN iteration 54 out of 74
# currently in KNN iteration 55 out of 74
# currently in KNN iteration 56 out of 74
# currently in KNN iteration 57 out of 74
# currently in KNN iteration 58 out of 74
# currently in KNN iteration 59 out of 74
# currently in KNN iteration 60 out of 74
# currently in KNN iteration 61 out of 74
# currently in KNN iteration 62 out of 74
# currently in KNN iteration 63 out of 74
# currently in KNN iteration 64 out of 74
# currently in KNN iteration 65 out of 74
# currently in KNN iteration 66 out of 74
# currently in KNN iteration 67 out of 74
# currently in KNN iteration 68 out of 74
# currently in KNN iteration 69 out of 74
# currently in KNN iteration 70 out of 74
# currently in KNN iteration 71 out of 74
# currently in KNN iteration 72 out of 74
# currently in KNN iteration 73 out of 74
# currently in KNN iteration 74 out of 74
# currently in KNN iteration 75 out of 74
# currently in KNN iteration 76 out of 74
# currently in KNN iteration 77 out of 74
# currently in KNN iteration 78 out of 74
# currently in KNN iteration 79 out of 74
# currently in KNN iteration 80 out of 74
# currently in KNN iteration 81 out of 74
# currently in KNN iteration 82 out of 74
# currently in KNN iteration 83 out of 74
# currently in KNN iteration 84 out of 74
# C:\Users\JanRuoYu\AppData\Local\Temp\ipykernel_28576\3549326197.py:31: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# The corresponding accuracy in tuning for KNN is 0.520165208384961
# The best hyper-parameter of KNN without deduction is:N_neighbors = 21,  Leaf_size = 15, and Distance_measure = 3
# The corresponding accuracy in tuning for KNN is 0.5158760520275439
# The model is: Random_forest+LSTM
# currently in LSTM iteration 1 out of 36
# currently in LSTM iteration 2 out of 36
# currently in LSTM iteration 3 out of 36
# currently in LSTM iteration 4 out of 36
# currently in LSTM iteration 5 out of 36
# Exception ignored in: <function ScopedTFGraph.__del__ at 0x0000028CE13C5280>
# Traceback (most recent call last):
#   File "C:\Users\JanRuoYu\.conda\envs\py39\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 54, in __del__
#     self.deleter(self.graph)
# KeyboardInterrupt:
#
# KeyboardInterrupt
